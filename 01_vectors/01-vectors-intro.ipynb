# %% [markdown]
# # Vectors and Linear Combinations
#
# Each page in the book is a Jupyter Notebook (file with extension `.ipynb`). You can edit these notebooks directly, and the changes will be reflected in the book. Jupyter Notebooks support code cells (none of which are on this specific page) and Markdown cells, like this one.
#
# Markdown cells support Markdown formatting:
# - This is a list.
# - This is how you **bold** something and *italicize* something.
# - Hyperlinks like [this](https://www.google.com) are easy to add, as are images.
#
# ```{image} https://upload.wikimedia.org/wikipedia/commons/5/57/University_of_Michigan_August_2013_157_%28Hatcher_Graduate_Library%29.jpg
# :alt: University of Michigan Hatcher Graduate Library
# :width: 500px
# :align: center
# ```
#
# And Markdown supports LaTeX, too.
#
# A vector in $\mathbb{R}^n$ is an ordered list of numbers. In this class, we will write vectors as column vectors:
#
# $$\vec v = \begin{bmatrix} 3 \\ -2 \\ \pi \end{bmatrix}$$
#
# A linear combination of vectors $\vec u$ and $\vec v$ has the form
#
# $$a\vec u + b\vec v$$
#
# If $\vec u = \begin{bmatrix} 1 \\ 0 \\ 2 \end{bmatrix}$ and $\vec v = \begin{bmatrix} 0 \\ 1 \\ 1 \end{bmatrix}$, then
#
# $$2\vec u - 3\vec v = \begin{bmatrix} 2 \\ -3 \\ 1 \end{bmatrix}$$
