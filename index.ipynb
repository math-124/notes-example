# %% [markdown]
# # Skeleton for Math 124 Notes
#
# This is a tiny Jupyter Book example for Math 124. It has two chapters, each with a few short pages. I have tried to include examples of different ways to format things (math, emphases, images, graphs, etc.)
#
# Click around the pages in the sidebar on the left.
